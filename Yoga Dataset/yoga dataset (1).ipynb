# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('final_asan1_1.csv')
df
# Out:
#      AID               AName  \
# 0      1     Padanguli Naman
# 1      2         Goolf Naman
# 2      3        Goolf Chakra
# 3      4       Goolf Ghooman
# 4      5  Janufalak Akarshan
# ..   ...                 ...
# 221  222        MOOLA BANDHA
# 222  223     UDDIYANA BANDHA
# 223  224         MAHA BANDHA
# 224  225           JALA NETI
# 225  226          SUTRA NETI
#
#                                            Description  \
# 0    Sit in the base position with the legs outstre...
# 1    Remain in the base position.\nSlowly move both...
# 2    Remain in the base position.\nKeep the legs sh...
# 3    Remain in the base position.\nBend the right k...
# 4    Stay in the base position.\nGently contract th...
# ..                                                 ...
# 221  Close the eyes and relax the whole body for a ...
# 222  Sit in siddha/siddha yoni asana or padmasana w...
# 223  Sit in siddha/siddha yoni asana or padmasana w...
# ...

# %%
df.head()
# Out:
#    AID               AName                                        Description  \
# 0    1     Padanguli Naman  Sit in the base position with the legs outstre...
# 1    2         Goolf Naman  Remain in the base position.\nSlowly move both...
# 2    3        Goolf Chakra  Remain in the base position.\nKeep the legs sh...
# 3    4       Goolf Ghooman  Remain in the base position.\nBend the right k...
# 4    5  Janufalak Akarshan  Stay in the base position.\nGently contract th...
#
#                                             Benefits Contraindications  \
# 0  This group of asanas is concerned with looseni...               NaN
# 1  This group of asanas is concerned with looseni...               NaN
# 2  This group of asanas is concerned with looseni...               NaN
# 3  All the foot and calf asanas help in returning...               NaN
# 4  This group of asanas is concerned with looseni...               NaN
#
#                                            Breathing  \
# ...

# %%
df.tail()
# Out:
#      AID            AName                                        Description  \
# 221  222     MOOLA BANDHA  Close the eyes and relax the whole body for a ...
# 222  223  UDDIYANA BANDHA  Sit in siddha/siddha yoni asana or padmasana w...
# 223  224      MAHA BANDHA  Sit in siddha/siddha yoni asana or padmasana w...
# 224  225        JALA NETI  A special neti lota, 'neti pof should be used....
# 225  226       SUTRA NETI  Take any comfortable standing, sitting or squa...
#
#                                               Benefits  \
# 221  Moola bandha bestows many physical, mental and...
# 222  Uddiyana bandha is a panacea for the abdomen. ...
# 223  Maha bandha gives enhanced benefits of all thr...
# 224  J ala neti removes mucus and pollution from th...
# 225  The benefits are the same as for jala neti. In...
#
#                                      Contraindications  \
# 221  This practice should only be performed\nunder ...
# 222  Persons suffering from colitis, stomach\nor in...
# ...

# %%
df.head(10)
# Out:
#    AID               AName                                        Description  \
# 0    1     Padanguli Naman  Sit in the base position with the legs outstre...
# 1    2         Goolf Naman  Remain in the base position.\nSlowly move both...
# 2    3        Goolf Chakra  Remain in the base position.\nKeep the legs sh...
# 3    4       Goolf Ghooman  Remain in the base position.\nBend the right k...
# 4    5  Janufalak Akarshan  Stay in the base position.\nGently contract th...
# 5    6          Janu Naman  Stage I: Stay in the base position. Bend the r...
# 6    7         Janu Chakra  Sit in the base position.\nBend the right knee...
# 7    8  Ardha Titali Asana  Sit in the base position.\nBend the right leg ...
# 8    9       Shroni Chakra  Sit in the same starting position as for ardha...
# 9   10  Pooma Titali Asana  Sit in the base position.\nBend the knees and ...
#
#                                             Benefits  \
# 0  This group of asanas is concerned with looseni...
# ...

# %%
df.tail(10)
# Out:
#      AID                                           AName  \
# 216  217                                MAHA BHEDA MUDRA
# 217  218  Maha Vedha Mudra (the great piercing attitude)
# 218  219                                   ASHWINI MUDRA
# 219  220                          VAJROLI/SAHAJOLI MUDRA
# 220  221                               JALANDHARA BANDHA
# 221  222                                    MOOLA BANDHA
# 222  223                                 UDDIYANA BANDHA
# 223  224                                     MAHA BANDHA
# 224  225                                       JALA NETI
# 225  226                                      SUTRA NETI
#
#                                            Description  \
# 216  Assume utthanpadasana as described for n1aha m...
# 217  Sit in padmasana. Relax the body and close the...
# 218  Technique I: Rapid contraction\nSit in any com...
# 219  Sit in siddha/siddha yoni asana, or any comfor...
# 220  Sit in padmasana or siddha/siddha yoni asana w...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AID                226 non-null    int64
#  1   AName              226 non-null    object
#  2   Description        225 non-null    object
#  3   Benefits           215 non-null    object
#  4   Contraindications  158 non-null    object
#  5   Breathing          188 non-null    object
#  6   awareness          186 non-null    object
#  7   You tube Vdo link  0 non-null      float64
#  8   Photo              0 non-null      float64
#  9   References         0 non-null      float64
#  10  Variations         51 non-null     object
#  11  Level              177 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 21.3+ KB

# %%
df
# Out:
#      AID               AName  \
# 0      1     Padanguli Naman
# 1      2         Goolf Naman
# 2      3        Goolf Chakra
# 3      4       Goolf Ghooman
# 4      5  Janufalak Akarshan
# ..   ...                 ...
# 221  222        MOOLA BANDHA
# 222  223     UDDIYANA BANDHA
# 223  224         MAHA BANDHA
# 224  225           JALA NETI
# 225  226          SUTRA NETI
#
#                                            Description  \
# 0    Sit in the base position with the legs outstre...
# 1    Remain in the base position.\nSlowly move both...
# 2    Remain in the base position.\nKeep the legs sh...
# 3    Remain in the base position.\nBend the right k...
# 4    Stay in the base position.\nGently contract th...
# ..                                                 ...
# 221  Close the eyes and relax the whole body for a ...
# 222  Sit in siddha/siddha yoni asana or padmasana w...
# 223  Sit in siddha/siddha yoni asana or padmasana w...
# ...

# %%
df["References"].fillna(2,inplace=True)

# %%
df['References'] = df['References'].replace(2,np.nan)

# %%
df['Photo'].fillna(4,inplace=True)

# %%
df['References'].fillna(5,inplace=True)

# %%
df['Photo'] = df['Photo'].replace(4,np.nan)

# %%
df['Photo'].fillna(3,inplace=True)

# %%
df
# Out:
#      AID               AName  \
# 0      1     Padanguli Naman
# 1      2         Goolf Naman
# 2      3        Goolf Chakra
# 3      4       Goolf Ghooman
# 4      5  Janufalak Akarshan
# ..   ...                 ...
# 221  222        MOOLA BANDHA
# 222  223     UDDIYANA BANDHA
# 223  224         MAHA BANDHA
# 224  225           JALA NETI
# 225  226          SUTRA NETI
#
#                                            Description  \
# 0    Sit in the base position with the legs outstre...
# 1    Remain in the base position.\nSlowly move both...
# 2    Remain in the base position.\nKeep the legs sh...
# 3    Remain in the base position.\nBend the right k...
# 4    Stay in the base position.\nGently contract th...
# ..                                                 ...
# 221  Close the eyes and relax the whole body for a ...
# 222  Sit in siddha/siddha yoni asana or padmasana w...
# 223  Sit in siddha/siddha yoni asana or padmasana w...
# ...

# %%
df.shape
# Out:
# (226, 12)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Length: 226, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# !pip install missingno

# %%
import missingno as ms # barchart, heatmap, dendrogram, matrix

# %%
ms.heatmap(df)
# Out:
# <AxesSubplot:>

# %%
ms.dendrogram(df)
# Out:
# <AxesSubplot:>

# %%
ms.bar(df)
# Out:
# <AxesSubplot:>

# %%
ms.matrix(df)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn

# %%
sn.distplot(df["AID"])
# Out:
# <AxesSubplot:xlabel='AID', ylabel='Density'>

# %%
sn.distplot(df["AID"],color='r')
# Out:
# <AxesSubplot:xlabel='AID', ylabel='Density'>

# %%
sn.distplot(df["Photo"],color='r')
# Out:
# <AxesSubplot:xlabel='Photo', ylabel='Density'>

# %%
df.isnull().sum()
# Out:
# AID                    0
# AName                  0
# Description            1
# Benefits              11
# Contraindications     68
# Breathing             38
# awareness             40
# You tube Vdo link    226
# Photo                  0
# References             0
# Variations           175
# Level                 49
# dtype: int64

# %%
uniqueName = []

# %%
df.columns
# Out:
# Index(['AID', 'AName', 'Description', 'Benefits', 'Contraindications',
#        'Breathing', 'awareness', 'You tube Vdo link', 'Photo', 'References',
#        'Variations', 'Level'],
#       dtype='object')

# %%
for i in df.columns:
    x = df[i].value_counts().count()
    uniqueName.append(x)

pd.DataFrame(uniqueName,index = df.columns,columns = ["Total unique values"])
# Out:
#                    Total unique values
# AID                                226
# AName                              226
# Description                        225
# Benefits                           202
# Contraindications                  143
# Breathing                          170
# awareness                          180
# You tube Vdo link                    0
# Photo                                1
# References                           1
# Variations                          49
# Level                                4

# %%
sns.distplot(df["AID"], hist=False)
# Out:
# <AxesSubplot:xlabel='AID', ylabel='Density'>

# %%
x,y = plt.subplots(figsize =(8,8))
sns.distplot(df["AID"], hist=False, ax=y)
y.axvline(df["AID"].mean(),color="r", ls="--")

# %%
x,y = plt.subplots(figsize =(8,8))
sns.distplot(df["AID"], hist=True, ax=y)
y.axvline(df["AID"].mean(),color="r", ls="--")

# %%
y = list(df.AID)
plt.boxplot(y)
plt.show()

# %%
sns.pairplot(df)

# %%
sns.catplot(data=df)

# %%
sns.catplot(
    data=df, kind="violin",
)

# %%
sns.catplot(data=df,kind="bar")

# %%
import scipy
from scipy import stats
from scipy.stats import zscore

# %%
from scipy.stats.mstats import winsorize

# %%
zscore_AID=zscore(df["AID"])
zscore_AID
# Out:
# 0     -1.724404
# 1     -1.709076
# 2     -1.693748
# 3     -1.678420
# 4     -1.663092
#          ...
# 221    1.663092
# 222    1.678420
# 223    1.693748
# 224    1.709076
# 225    1.724404
# Name: AID, Length: 226, dtype: float64
